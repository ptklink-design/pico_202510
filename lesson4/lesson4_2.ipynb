# %%
from errno import ESTALE


age = int(input("輸入年紀:"))
if age >= 18:
    print("滿十八歲,可以考駕照了")
else:
    print("未滿十八歲，不可考駕照")
    print(f"再等{18-age}年，就可以考駕照")
print("結束程式")
# Out:
# 未滿十八歲，不可考駕照
# 再等6年，就可以考駕照
# 結束程式

# %%
#巢狀判斷
age = int(input("輸入年紀:"))
if age < 18:
    print("未滿十八")
elif age<=25:
    print("18~25")
else:
    print("26以上")
# Out:
# 未滿十八

# %%
score = 59
if score >= 90:
    print("優")
elif score >= 80:
    print("甲")
elif score >= 70:
    print("乙")
elif score >= 60:
    print("丙")
else:
    print("丁")
# Out:
# 丁

# %%
presuer = 78
if presuer >=90 and presuer <=120:
    print("正常")
else:
    print("不正常")
# Out:
# 不正常

# %%
presuer = 89
if not(presuer >=90 and presuer <=120):
    print("不正常")
else:
    print("正常")
# Out:
# 不正常

# %%
score = 85
if score >= 90:
    print("優")
elif 90 > score >= 80:
    print("甲")
elif score >= 70:
    print("乙")
elif score >= 60:
    print("丙")
else:
    print("丁")
# Out:
# 甲
